# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
#matplotlib inline
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
Bank_cust = pd.read_excel('Bank_churn_II.xlsx')
Bank_account = pd.read_excel('Bank_churn_II.xlsx', sheet_name = 'Customer_Info (2)')
Comb_df = pd.merge(Bank_cust,Bank_account, on = 'CustomerId', how='left')
Comb_df
# Out:
#        CustomerId  Balance  NumOfProducts HasCrCard  Tenure_x IsActiveMember  \
# 0        15634602        0              1       Yes         2            Yes
# 1        15634602        0              1       Yes         2            Yes
# 2        15619304   159660              3        No         8             No
# 3        15701354        0              2        No         1             No
# 4        15737888   125510              1       Yes         2            Yes
# ...           ...      ...            ...       ...       ...            ...
# 9998     15682355    75075              2        No         3             No
# 9999     15628319   130142              1        No         4             No
# 10000    15628319   130142              1        No         4             No
# 10001    15628319   130142              1        No         4             No
# 10002    15628319   130142              1        No         4             No
#
#        Exited    Surname  CreditScore Geography  Gender   Age  Tenure_y  \
# 0           1   Hargrave          619       FRA  Female  42.0         2
# 1           1   Hargrave          619       FRA  Female  42.0         2
# 2           1       Onio          502    French  Female  42.0         8
# 3           0       Boni          699       FRA  Female  39.0         1
# 4           0   Mitchell          850     Spain  Female  43.0         2
# ...       ...        ...          ...       ...     ...   ...       ...
# 9998        1  Sabbatini          772   Germany    Male  42.0         3
# 9999        0     Walker          792    French  Female  28.0         4
# 10000       0     Walker          792    French  Female  28.0         4
# 10001       0     Walker          792    French  Female  28.0         4
# 10002       0     Walker          792    French  Female  28.0         4
#
#        EstimatedSalary
# 0               101348
# 1               101348
# 2               113931
# 3                93826
# 4                79084
# ...                ...
# 9998             92888
# 9999             38190
# 10000            38190
# 10001            38190
# 10002            38190
#
# [10003 rows x 14 columns]

# %%
Comb_df.drop(columns=['Tenure_y'], inplace=True)

# %%
Comb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10003 entries, 0 to 10002
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10003 non-null  int64
#  1   Balance          10003 non-null  int64
#  2   NumOfProducts    10003 non-null  int64
#  3   HasCrCard        10003 non-null  object
#  4   Tenure_x         10003 non-null  int64
#  5   IsActiveMember   10003 non-null  object
#  6   Exited           10003 non-null  int64
#  7   Surname          10000 non-null  object
#  8   CreditScore      10003 non-null  int64
#  9   Geography        10003 non-null  object
#  10  Gender           10003 non-null  object
#  11  Age              10000 non-null  float64
#  12  EstimatedSalary  10003 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 1.1+ MB

# %%
Comb_df.duplicated().sum()
# Out:
# 4

# %%
Comb_df.drop_duplicates(inplace=True)

# %%
Comb_df.rename(columns={"Surname" : 'Name'}, inplace=True)

# %%
Comb_df
# Out:
#       CustomerId  Balance  NumOfProducts HasCrCard  Tenure_x IsActiveMember  \
# 0       15634602        0              1       Yes         2            Yes
# 2       15619304   159660              3        No         8             No
# 3       15701354        0              2        No         1             No
# 4       15737888   125510              1       Yes         2            Yes
# 5       15574012   113755              2        No         8             No
# ...          ...      ...            ...       ...       ...            ...
# 9995    15606229        0              2        No         5             No
# 9996    15569892    57369              1       Yes        10            Yes
# 9997    15584532        0              1       Yes         7            Yes
# 9998    15682355    75075              2        No         3             No
# 9999    15628319   130142              1        No         4             No
#
#       Exited       Name  CreditScore Geography  Gender   Age  EstimatedSalary
# 0          1   Hargrave          619       FRA  Female  42.0           101348
# 2          1       Onio          502    French  Female  42.0           113931
# 3          0       Boni          699       FRA  Female  39.0            93826
# 4          0   Mitchell          850     Spain  Female  43.0            79084
# 5          1        Chu          645     Spain    Male  44.0           149756
# ...      ...        ...          ...       ...     ...   ...              ...
# 9995       0   Obijiaku          771    France    Male  39.0            96270
# 9996       0  Johnstone          516    French    Male  35.0           101699
# 9997       1        Liu          709       FRA  Female  36.0            42085
# 9998       1  Sabbatini          772   Germany    Male  42.0            92888
# 9999       0     Walker          792    French  Female  28.0            38190
#
# [9999 rows x 13 columns]

# %%
Comb_df.isnull().sum()
# Out:
# CustomerId         0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# Tenure_x           0
# IsActiveMember     0
# Exited             0
# Name               3
# CreditScore        0
# Geography          0
# Gender             0
# Age                3
# EstimatedSalary    0
# dtype: int64

# %%
Comb_df.dropna(inplace=True)

# %%
Comb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9996 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       9996 non-null   int64
#  1   Balance          9996 non-null   int64
#  2   NumOfProducts    9996 non-null   int64
#  3   HasCrCard        9996 non-null   object
#  4   Tenure_x         9996 non-null   int64
#  5   IsActiveMember   9996 non-null   object
#  6   Exited           9996 non-null   int64
#  7   Name             9996 non-null   object
#  8   CreditScore      9996 non-null   int64
#  9   Geography        9996 non-null   object
#  10  Gender           9996 non-null   object
#  11  Age              9996 non-null   float64
#  12  EstimatedSalary  9996 non-null   int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 1.1+ MB

# %%
Comb_df_copy = Comb_df.copy ()

# %%
Comb_df['Geography'] = Comb_df['Geography'].replace(r'(?i)French', 'France', regex=True)

# %%
Comb_df
# Out:
#       CustomerId  Balance  NumOfProducts HasCrCard  Tenure_x IsActiveMember  \
# 0       15634602        0              1       Yes         2            Yes
# 2       15619304   159660              3        No         8             No
# 3       15701354        0              2        No         1             No
# 4       15737888   125510              1       Yes         2            Yes
# 5       15574012   113755              2        No         8             No
# ...          ...      ...            ...       ...       ...            ...
# 9995    15606229        0              2        No         5             No
# 9996    15569892    57369              1       Yes        10            Yes
# 9997    15584532        0              1       Yes         7            Yes
# 9998    15682355    75075              2        No         3             No
# 9999    15628319   130142              1        No         4             No
#
#       Exited       Name  CreditScore Geography  Gender   Age  EstimatedSalary
# 0          1   Hargrave          619       FRA  Female  42.0           101348
# 2          1       Onio          502    France  Female  42.0           113931
# 3          0       Boni          699       FRA  Female  39.0            93826
# 4          0   Mitchell          850     Spain  Female  43.0            79084
# 5          1        Chu          645     Spain    Male  44.0           149756
# ...      ...        ...          ...       ...     ...   ...              ...
# 9995       0   Obijiaku          771    France    Male  39.0            96270
# 9996       0  Johnstone          516    France    Male  35.0           101699
# 9997       1        Liu          709       FRA  Female  36.0            42085
# 9998       1  Sabbatini          772   Germany    Male  42.0            92888
# 9999       0     Walker          792    France  Female  28.0            38190
#
# [9996 rows x 13 columns]

# %%
Comb_df.head(20)
# Out:
#     CustomerId  Balance  NumOfProducts HasCrCard  Tenure_x IsActiveMember  \
# 0     15634602        0              1       Yes         2            Yes
# 2     15619304   159660              3        No         8             No
# 3     15701354        0              2        No         1             No
# 4     15737888   125510              1       Yes         2            Yes
# 5     15574012   113755              2        No         8             No
# 6     15592531        0              2       Yes         7            Yes
# 7     15656148   115046              4        No         4             No
# 8     15792365   142051              2       Yes         4            Yes
# 9     15592389   134603              1       Yes         2            Yes
# 10    15767821   102016              2        No         6             No
# 11    15737173        0              2        No         3             No
# 12    15632264        0              2        No        10             No
# 13    15691483        0              2        No         5             No
# 14    15600882        0              2       Yes         7            Yes
# 15    15643966   143129              2       Yes         3            Yes
# 16    15737452   132602              1        No         1             No
# 17    15788218        0              2       Yes         9            Yes
# 18    15661507        0              1        No         6             No
# 19    15568982        0              2       Yes         6            Yes
# 20    15577657        0              2       Yes         8            Yes
#
#     Exited       Name  CreditScore Geography  Gender   Age  EstimatedSalary
# 0        1   Hargrave          619       FRA  Female  42.0           101348
# 2        1       Onio          502    France  Female  42.0           113931
# 3        0       Boni          699       FRA  Female  39.0            93826
# 4        0   Mitchell          850     Spain  Female  43.0            79084
# 5        1        Chu          645     Spain    Male  44.0           149756
# 6        0   Bartlett          822    France    Male  50.0            10062
# 7        1     Obinna          376   Germany  Female  29.0           119346
# 8        0         He          501    France    Male  44.0            74940
# 9        0         H?          684    France    Male  27.0            71725
# 10       0     Bearce          528    France    Male  31.0            80181
# 11       0    Andrews          497     Spain    Male  24.0            76390
# 12       0        Kay          476       FRA  Female  34.0            26260
# 13       0       Chin          549    France  Female  25.0           190857
# 14       0      Scott          635     Spain  Female  35.0            65951
# 15       0    Goforth          616   Germany    Male  45.0            64327
# 16       1      Romeo          653   Germany    Male  58.0             5097
# 17       0  Henderson          549     Spain  Female  24.0            14406
# 18       0    Muldrow          587     Spain    Male  45.0           158684
# 19       0        Hao          726    France  Female  24.0            54724
# 20       0   McDonald          732    France    Male  41.0           170886

# %%
Comb_df['Geography'] = Comb_df['Geography'].replace('Francence', 'France')

# %%
Comb_df
# Out:
#       CustomerId  Balance  NumOfProducts HasCrCard  Tenure_x IsActiveMember  \
# 0       15634602        0              1       Yes         2            Yes
# 2       15619304   159660              3        No         8             No
# 3       15701354        0              2        No         1             No
# 4       15737888   125510              1       Yes         2            Yes
# 5       15574012   113755              2        No         8             No
# ...          ...      ...            ...       ...       ...            ...
# 9995    15606229        0              2        No         5             No
# 9996    15569892    57369              1       Yes        10            Yes
# 9997    15584532        0              1       Yes         7            Yes
# 9998    15682355    75075              2        No         3             No
# 9999    15628319   130142              1        No         4             No
#
#       Exited       Name  CreditScore Geography  Gender   Age  EstimatedSalary
# 0          1   Hargrave          619       FRA  Female  42.0           101348
# 2          1       Onio          502    France  Female  42.0           113931
# 3          0       Boni          699       FRA  Female  39.0            93826
# 4          0   Mitchell          850     Spain  Female  43.0            79084
# 5          1        Chu          645     Spain    Male  44.0           149756
# ...      ...        ...          ...       ...     ...   ...              ...
# 9995       0   Obijiaku          771    France    Male  39.0            96270
# 9996       0  Johnstone          516    France    Male  35.0           101699
# 9997       1        Liu          709       FRA  Female  36.0            42085
# 9998       1  Sabbatini          772   Germany    Male  42.0            92888
# 9999       0     Walker          792    France  Female  28.0            38190
#
# [9996 rows x 13 columns]

# %%
Comb_df['Geography'] = Comb_df['Geography'].replace('FRA', 'France')

# %%
Comb_df.head(20)
# Out:
#     CustomerId  Balance  NumOfProducts HasCrCard  Tenure_x IsActiveMember  \
# 0     15634602        0              1       Yes         2            Yes
# 2     15619304   159660              3        No         8             No
# 3     15701354        0              2        No         1             No
# 4     15737888   125510              1       Yes         2            Yes
# 5     15574012   113755              2        No         8             No
# 6     15592531        0              2       Yes         7            Yes
# 7     15656148   115046              4        No         4             No
# 8     15792365   142051              2       Yes         4            Yes
# 9     15592389   134603              1       Yes         2            Yes
# 10    15767821   102016              2        No         6             No
# 11    15737173        0              2        No         3             No
# 12    15632264        0              2        No        10             No
# 13    15691483        0              2        No         5             No
# 14    15600882        0              2       Yes         7            Yes
# 15    15643966   143129              2       Yes         3            Yes
# 16    15737452   132602              1        No         1             No
# 17    15788218        0              2       Yes         9            Yes
# 18    15661507        0              1        No         6             No
# 19    15568982        0              2       Yes         6            Yes
# 20    15577657        0              2       Yes         8            Yes
#
#     Exited       Name  CreditScore Geography  Gender   Age  EstimatedSalary
# 0        1   Hargrave          619    France  Female  42.0           101348
# 2        1       Onio          502    France  Female  42.0           113931
# 3        0       Boni          699    France  Female  39.0            93826
# 4        0   Mitchell          850     Spain  Female  43.0            79084
# 5        1        Chu          645     Spain    Male  44.0           149756
# 6        0   Bartlett          822    France    Male  50.0            10062
# 7        1     Obinna          376   Germany  Female  29.0           119346
# 8        0         He          501    France    Male  44.0            74940
# 9        0         H?          684    France    Male  27.0            71725
# 10       0     Bearce          528    France    Male  31.0            80181
# 11       0    Andrews          497     Spain    Male  24.0            76390
# 12       0        Kay          476    France  Female  34.0            26260
# 13       0       Chin          549    France  Female  25.0           190857
# 14       0      Scott          635     Spain  Female  35.0            65951
# 15       0    Goforth          616   Germany    Male  45.0            64327
# 16       1      Romeo          653   Germany    Male  58.0             5097
# 17       0  Henderson          549     Spain  Female  24.0            14406
# 18       0    Muldrow          587     Spain    Male  45.0           158684
# 19       0        Hao          726    France  Female  24.0            54724
# 20       0   McDonald          732    France    Male  41.0           170886

# %%
Comb_df_exited = Comb_df.groupby('Geography')[['Exited']].sum()

# %%
Comb_df_exited
# Out:
#            Exited
# Geography
# France        810
# Germany       814
# Spain         413

# %%
import math
Comb_df.tail()
# Out:
#       CustomerId  Balance  NumOfProducts HasCrCard  Tenure_x IsActiveMember  \
# 9995    15606229        0              2        No         5             No
# 9996    15569892    57369              1       Yes        10            Yes
# 9997    15584532        0              1       Yes         7            Yes
# 9998    15682355    75075              2        No         3             No
# 9999    15628319   130142              1        No         4             No
#
#       Exited       Name  CreditScore Geography  Gender   Age  EstimatedSalary
# 9995       0   Obijiaku          771    France    Male  39.0            96270
# 9996       0  Johnstone          516    France    Male  35.0           101699
# 9997       1        Liu          709    France  Female  36.0            42085
# 9998       1  Sabbatini          772   Germany    Male  42.0            92888
# 9999       0     Walker          792    France  Female  28.0            38190

# %%
Comb_df['Age'] = Comb_df['Age'].fillna(0).astype(int)
Comb_df['Age'] = Comb_df['Age'].apply(lambda x: int(x))
Comb_df
# Out:
#       CustomerId  Balance  NumOfProducts HasCrCard  Tenure_x IsActiveMember  \
# 0       15634602        0              1       Yes         2            Yes
# 2       15619304   159660              3        No         8             No
# 3       15701354        0              2        No         1             No
# 4       15737888   125510              1       Yes         2            Yes
# 5       15574012   113755              2        No         8             No
# ...          ...      ...            ...       ...       ...            ...
# 9995    15606229        0              2        No         5             No
# 9996    15569892    57369              1       Yes        10            Yes
# 9997    15584532        0              1       Yes         7            Yes
# 9998    15682355    75075              2        No         3             No
# 9999    15628319   130142              1        No         4             No
#
#       Exited       Name  CreditScore Geography  Gender  Age  EstimatedSalary
# 0          1   Hargrave          619    France  Female   42           101348
# 2          1       Onio          502    France  Female   42           113931
# 3          0       Boni          699    France  Female   39            93826
# 4          0   Mitchell          850     Spain  Female   43            79084
# 5          1        Chu          645     Spain    Male   44           149756
# ...      ...        ...          ...       ...     ...  ...              ...
# 9995       0   Obijiaku          771    France    Male   39            96270
# 9996       0  Johnstone          516    France    Male   35           101699
# 9997       1        Liu          709    France  Female   36            42085
# 9998       1  Sabbatini          772   Germany    Male   42            92888
# 9999       0     Walker          792    France  Female   28            38190
#
# [9996 rows x 13 columns]

# %%
def classify_age(age):
    if age >= 65:
        return 'Retired'
    elif age >= 30:
        return 'Working class'
    else:
        return 'Student'

Comb_df['Age Group'] = Comb_df['Age'].apply(classify_age)

print(Comb_df)
# Out:
#       CustomerId  Balance  NumOfProducts HasCrCard  Tenure_x IsActiveMember  \
# 0       15634602        0              1       Yes         2            Yes
# 2       15619304   159660              3        No         8             No
# 3       15701354        0              2        No         1             No
# 4       15737888   125510              1       Yes         2            Yes
# 5       15574012   113755              2        No         8             No
# ...          ...      ...            ...       ...       ...            ...
# 9995    15606229        0              2        No         5             No
# 9996    15569892    57369              1       Yes        10            Yes
# 9997    15584532        0              1       Yes         7            Yes
# 9998    15682355    75075              2        No         3             No
# 9999    15628319   130142              1        No         4             No
#
#       Exited       Name  CreditScore Geography  Gender  Age  EstimatedSalary  \
# 0          1   Hargrave          619    France  Female   42           101348
# 2          1       Onio          502    France  Female   42           113931
# 3          0       Boni          699    France  Female   39            93826
# 4          0   Mitchell          850     Spain  Female   43            79084
# 5          1        Chu          645     Spain    Male   44           149756
# ...      ...        ...          ...       ...     ...  ...              ...
# 9995       0   Obijiaku          771    France    Male   39            96270
# 9996       0  Johnstone          516    France    Male   35           101699
# 9997       1        Liu          709    France  Female   36            42085
# 9998       1  Sabbatini          772   Germany    Male   42            92888
# 9999       0     Walker          792    France  Female   28            38190
#
#           Age Group
# 0     Working class
# 2     Working class
# 3     Working class
# 4     Working class
# 5     Working class
# ...             ...
# 9995  Working class
# 9996  Working class
# 9997  Working class
# 9998  Working class
# 9999        Student
#
# [9996 rows x 14 columns]

# %%
Comb_df.head(20)
# Out:
#     CustomerId  Balance  NumOfProducts HasCrCard  Tenure_x IsActiveMember  \
# 0     15634602        0              1       Yes         2            Yes
# 2     15619304   159660              3        No         8             No
# 3     15701354        0              2        No         1             No
# 4     15737888   125510              1       Yes         2            Yes
# 5     15574012   113755              2        No         8             No
# 6     15592531        0              2       Yes         7            Yes
# 7     15656148   115046              4        No         4             No
# 8     15792365   142051              2       Yes         4            Yes
# 9     15592389   134603              1       Yes         2            Yes
# 10    15767821   102016              2        No         6             No
# 11    15737173        0              2        No         3             No
# 12    15632264        0              2        No        10             No
# 13    15691483        0              2        No         5             No
# 14    15600882        0              2       Yes         7            Yes
# 15    15643966   143129              2       Yes         3            Yes
# 16    15737452   132602              1        No         1             No
# 17    15788218        0              2       Yes         9            Yes
# 18    15661507        0              1        No         6             No
# 19    15568982        0              2       Yes         6            Yes
# 20    15577657        0              2       Yes         8            Yes
#
#     Exited       Name  CreditScore Geography  Gender  Age  EstimatedSalary  \
# 0        1   Hargrave          619    France  Female   42           101348
# 2        1       Onio          502    France  Female   42           113931
# 3        0       Boni          699    France  Female   39            93826
# 4        0   Mitchell          850     Spain  Female   43            79084
# 5        1        Chu          645     Spain    Male   44           149756
# 6        0   Bartlett          822    France    Male   50            10062
# 7        1     Obinna          376   Germany  Female   29           119346
# 8        0         He          501    France    Male   44            74940
# 9        0         H?          684    France    Male   27            71725
# 10       0     Bearce          528    France    Male   31            80181
# 11       0    Andrews          497     Spain    Male   24            76390
# 12       0        Kay          476    France  Female   34            26260
# 13       0       Chin          549    France  Female   25           190857
# 14       0      Scott          635     Spain  Female   35            65951
# 15       0    Goforth          616   Germany    Male   45            64327
# 16       1      Romeo          653   Germany    Male   58             5097
# 17       0  Henderson          549     Spain  Female   24            14406
# 18       0    Muldrow          587     Spain    Male   45           158684
# 19       0        Hao          726    France  Female   24            54724
# 20       0   McDonald          732    France    Male   41           170886
#
#         Age Group
# 0   Working class
# 2   Working class
# 3   Working class
# 4   Working class
# 5   Working class
# 6   Working class
# 7         Student
# 8   Working class
# 9         Student
# 10  Working class
# 11        Student
# 12  Working class
# 13        Student
# 14  Working class
# 15  Working class
# 16  Working class
# 17        Student
# 18  Working class
# 19        Student
# 20  Working class

# %%
Comb_df_age_group = Comb_df.groupby('Age Group')[['Exited']].sum()
Comb_df_age_group
# Out:
#                Exited
# Age Group
# Retired            43
# Student           124
# Working class    1870

# %%
Comb_df['HasCrCard'] = Comb_df['HasCrCard'].replace({'Yes': 1, 'No': 0} )
Comb_df_cr_card = Comb_df.groupby('Age Group')[['HasCrCard']].sum()
Comb_df_cr_card
# Out:
#                HasCrCard
# Age Group
# Retired              244
# Student              837
# Working class       4067

# %%
Comb_df_card_by_country = Comb_df.groupby('Geography')[['HasCrCard']].sum()
Comb_df_card_by_country
# Out:
#            HasCrCard
# Geography
# France          2590
# Germany         1247
# Spain           1311

# %%
counts_Age = Comb_df.groupby(['Geography', 'Age Group']).size().reset_index(name='Count')
counts_Age
# Out:
#   Geography      Age Group  Count
# 0    France        Retired    141
# 1    France        Student    866
# 2    France  Working class   4006
# 3   Germany        Retired     70
# 4   Germany        Student    372
# 5   Germany  Working class   2066
# 6     Spain        Retired     71
# 7     Spain        Student    403
# 8     Spain  Working class   2001

# %%
#Comb_df.drop(columns=['Tenure_y'], inplace=True)

# %%
def classify_tenure(tenure):
    if tenure <= 5:
        return 'Short term cust'
    else:
        return 'Long term cust'

Comb_df['Tenure Group'] = Comb_df['Tenure_x'].apply(classify_tenure)

print(Comb_df)
# Out:
#       CustomerId  Balance  NumOfProducts  HasCrCard  Tenure_x IsActiveMember  \
# 0       15634602        0              1          1         2            Yes
# 2       15619304   159660              3          0         8             No
# 3       15701354        0              2          0         1             No
# 4       15737888   125510              1          1         2            Yes
# 5       15574012   113755              2          0         8             No
# ...          ...      ...            ...        ...       ...            ...
# 9995    15606229        0              2          0         5             No
# 9996    15569892    57369              1          1        10            Yes
# 9997    15584532        0              1          1         7            Yes
# 9998    15682355    75075              2          0         3             No
# 9999    15628319   130142              1          0         4             No
#
#       Exited       Name  CreditScore Geography  Gender  Age  EstimatedSalary  \
# 0          1   Hargrave          619    France  Female   42           101348
# 2          1       Onio          502    France  Female   42           113931
# 3          0       Boni          699    France  Female   39            93826
# 4          0   Mitchell          850     Spain  Female   43            79084
# 5          1        Chu          645     Spain    Male   44           149756
# ...      ...        ...          ...       ...     ...  ...              ...
# 9995       0   Obijiaku          771    France    Male   39            96270
# 9996       0  Johnstone          516    France    Male   35           101699
# 9997       1        Liu          709    France  Female   36            42085
# 9998       1  Sabbatini          772   Germany    Male   42            92888
# 9999       0     Walker          792    France  Female   28            38190
#
#           Age Group     Tenure Group
# 0     Working class  Short term cust
# 2     Working class   Long term cust
# 3     Working class  Short term cust
# 4     Working class  Short term cust
# 5     Working class   Long term cust
# ...             ...              ...
# 9995  Working class  Short term cust
# 9996  Working class   Long term cust
# 9997  Working class   Long term cust
# 9998  Working class  Short term cust
# 9999        Student  Short term cust
#
# [9996 rows x 15 columns]

# %%
Comb_df
# Out:
#       CustomerId  Balance  NumOfProducts  HasCrCard  Tenure_x IsActiveMember  \
# 0       15634602        0              1          1         2            Yes
# 2       15619304   159660              3          0         8             No
# 3       15701354        0              2          0         1             No
# 4       15737888   125510              1          1         2            Yes
# 5       15574012   113755              2          0         8             No
# ...          ...      ...            ...        ...       ...            ...
# 9995    15606229        0              2          0         5             No
# 9996    15569892    57369              1          1        10            Yes
# 9997    15584532        0              1          1         7            Yes
# 9998    15682355    75075              2          0         3             No
# 9999    15628319   130142              1          0         4             No
#
#       Exited       Name  CreditScore Geography  Gender  Age  EstimatedSalary  \
# 0          1   Hargrave          619    France  Female   42           101348
# 2          1       Onio          502    France  Female   42           113931
# 3          0       Boni          699    France  Female   39            93826
# 4          0   Mitchell          850     Spain  Female   43            79084
# 5          1        Chu          645     Spain    Male   44           149756
# ...      ...        ...          ...       ...     ...  ...              ...
# 9995       0   Obijiaku          771    France    Male   39            96270
# 9996       0  Johnstone          516    France    Male   35           101699
# 9997       1        Liu          709    France  Female   36            42085
# 9998       1  Sabbatini          772   Germany    Male   42            92888
# 9999       0     Walker          792    France  Female   28            38190
#
#           Age Group     Tenure Group
# 0     Working class  Short term cust
# 2     Working class   Long term cust
# 3     Working class  Short term cust
# 4     Working class  Short term cust
# 5     Working class   Long term cust
# ...             ...              ...
# 9995  Working class  Short term cust
# 9996  Working class   Long term cust
# 9997  Working class   Long term cust
# 9998  Working class  Short term cust
# 9999        Student  Short term cust
#
# [9996 rows x 15 columns]

# %%
Comb_df_Tenure = Comb_df.groupby('Tenure Group')[['Exited']].sum()
Comb_df_Tenure
# Out:
#                  Exited
# Tenure Group
# Long term cust      884
# Short term cust    1153

# %%
counts_Gender = Comb_df.groupby(['Geography', 'Gender']).size().reset_index(name='Count')
counts_Gender
# Out:
#   Geography  Gender  Count
# 0    France  Female   2260
# 1    France    Male   2753
# 2   Germany  Female   1192
# 3   Germany    Male   1316
# 4     Spain  Female   1088
# 5     Spain    Male   1387

# %%
Comb_df_credit = Comb_df.groupby('Gender')[['CreditScore']].sum()
Comb_df_credit
# Out:
#         CreditScore
# Gender
# Female      2955007
# Male        3547887

# %%
Comb_df_Gender_Exit = Comb_df.groupby('Gender')[['Exited']].sum()
Comb_df_Gender_Exit
# Out:
#         Exited
# Gender
# Female    1139
# Male       898

# %%
Comb_df['IsActiveMember'] = Comb_df['IsActiveMember'].replace({'Yes': 1, 'No': 0} )

# %%
Comb_df_ActiveMember = Comb_df.groupby('Gender')[['IsActiveMember']].sum()
Comb_df_ActiveMember
# Out:
#         IsActiveMember
# Gender
# Female            2281
# Male              2867

# %%
Comb_df_Active_exited = Comb_df.groupby('IsActiveMember')[['Exited']].sum()
Comb_df_Active_exited
# Out:
#                 Exited
# IsActiveMember
# 0                 1302
# 1                  735

# %%
Comb_df_product_exited = Comb_df.groupby('NumOfProducts')[['Exited']].sum()
Comb_df_product_exited
# Out:
#                Exited
# NumOfProducts
# 1                1409
# 2                 348
# 3                 220
# 4                  60

# %%
max_salary = Comb_df['EstimatedSalary'].max()
max_salary
# Out:
# 199992

# %%
max_bal = Comb_df['Balance'].max()
max_bal
# Out:
# 250898

# %%
def classify_salary(salary):
    if salary >= 99992:
        return 'High earner'
    elif salary >= 49992 :
        return 'Fair earner'
    else:
        return 'low earner'

Comb_df['Salary Group'] = Comb_df['EstimatedSalary'].apply(classify_salary)

print(Comb_df)
# Out:
#       CustomerId  Balance  NumOfProducts  HasCrCard  Tenure_x  IsActiveMember  \
# 0       15634602        0              1          1         2               1
# 2       15619304   159660              3          0         8               0
# 3       15701354        0              2          0         1               0
# 4       15737888   125510              1          1         2               1
# 5       15574012   113755              2          0         8               0
# ...          ...      ...            ...        ...       ...             ...
# 9995    15606229        0              2          0         5               0
# 9996    15569892    57369              1          1        10               1
# 9997    15584532        0              1          1         7               1
# 9998    15682355    75075              2          0         3               0
# 9999    15628319   130142              1          0         4               0
#
#       Exited       Name  CreditScore Geography  Gender  Age  EstimatedSalary  \
# 0          1   Hargrave          619    France  Female   42           101348
# 2          1       Onio          502    France  Female   42           113931
# 3          0       Boni          699    France  Female   39            93826
# 4          0   Mitchell          850     Spain  Female   43            79084
# 5          1        Chu          645     Spain    Male   44           149756
# ...      ...        ...          ...       ...     ...  ...              ...
# 9995       0   Obijiaku          771    France    Male   39            96270
# 9996       0  Johnstone          516    France    Male   35           101699
# 9997       1        Liu          709    France  Female   36            42085
# 9998       1  Sabbatini          772   Germany    Male   42            92888
# 9999       0     Walker          792    France  Female   28            38190
#
#           Age Group     Tenure Group Salary Group
# 0     Working class  Short term cust  High earner
# 2     Working class   Long term cust  High earner
# 3     Working class  Short term cust  Fair earner
# 4     Working class  Short term cust  Fair earner
# 5     Working class   Long term cust  High earner
# ...             ...              ...          ...
# 9995  Working class  Short term cust  Fair earner
# 9996  Working class   Long term cust  High earner
# 9997  Working class   Long term cust   low earner
# 9998  Working class  Short term cust  Fair earner
# 9999        Student  Short term cust   low earner
#
# [9996 rows x 16 columns]

# %%
Comb_df.head(20)
# Out:
#     CustomerId  Balance  NumOfProducts  HasCrCard  Tenure_x  IsActiveMember  \
# 0     15634602        0              1          1         2               1
# 2     15619304   159660              3          0         8               0
# 3     15701354        0              2          0         1               0
# 4     15737888   125510              1          1         2               1
# 5     15574012   113755              2          0         8               0
# 6     15592531        0              2          1         7               1
# 7     15656148   115046              4          0         4               0
# 8     15792365   142051              2          1         4               1
# 9     15592389   134603              1          1         2               1
# 10    15767821   102016              2          0         6               0
# 11    15737173        0              2          0         3               0
# 12    15632264        0              2          0        10               0
# 13    15691483        0              2          0         5               0
# 14    15600882        0              2          1         7               1
# 15    15643966   143129              2          1         3               1
# 16    15737452   132602              1          0         1               0
# 17    15788218        0              2          1         9               1
# 18    15661507        0              1          0         6               0
# 19    15568982        0              2          1         6               1
# 20    15577657        0              2          1         8               1
#
#     Exited       Name  CreditScore Geography  Gender  Age  EstimatedSalary  \
# 0        1   Hargrave          619    France  Female   42           101348
# 2        1       Onio          502    France  Female   42           113931
# 3        0       Boni          699    France  Female   39            93826
# 4        0   Mitchell          850     Spain  Female   43            79084
# 5        1        Chu          645     Spain    Male   44           149756
# 6        0   Bartlett          822    France    Male   50            10062
# 7        1     Obinna          376   Germany  Female   29           119346
# 8        0         He          501    France    Male   44            74940
# 9        0         H?          684    France    Male   27            71725
# 10       0     Bearce          528    France    Male   31            80181
# 11       0    Andrews          497     Spain    Male   24            76390
# 12       0        Kay          476    France  Female   34            26260
# 13       0       Chin          549    France  Female   25           190857
# 14       0      Scott          635     Spain  Female   35            65951
# 15       0    Goforth          616   Germany    Male   45            64327
# 16       1      Romeo          653   Germany    Male   58             5097
# 17       0  Henderson          549     Spain  Female   24            14406
# 18       0    Muldrow          587     Spain    Male   45           158684
# 19       0        Hao          726    France  Female   24            54724
# 20       0   McDonald          732    France    Male   41           170886
#
#         Age Group     Tenure Group Salary Group
# 0   Working class  Short term cust  High earner
# 2   Working class   Long term cust  High earner
# 3   Working class  Short term cust  Fair earner
# 4   Working class  Short term cust  Fair earner
# 5   Working class   Long term cust  High earner
# 6   Working class   Long term cust   low earner
# 7         Student  Short term cust  High earner
# 8   Working class  Short term cust  Fair earner
# 9         Student  Short term cust  Fair earner
# 10  Working class   Long term cust  Fair earner
# 11        Student  Short term cust  Fair earner
# 12  Working class   Long term cust   low earner
# 13        Student  Short term cust  High earner
# 14  Working class   Long term cust  Fair earner
# 15  Working class  Short term cust  Fair earner
# 16  Working class  Short term cust   low earner
# 17        Student   Long term cust   low earner
# 18  Working class   Long term cust  High earner
# 19        Student   Long term cust  Fair earner
# 20  Working class   Long term cust  High earner

# %%
Comb_df_earners_exited = Comb_df.groupby('Salary Group')[['Exited']].sum()
Comb_df_earners_exited
# Out:
#               Exited
# Salary Group
# Fair earner      504
# High earner     1044
# low earner       489

# %%
def classify_balance(balance):
    if balance >= 250898:
        return 'High balance'
    elif balance >= 150898 :
        return 'Fair balance'
    elif balance >= 50898 :
        return 'low balance'
    else:
        return 'Very low balance'

Comb_df['Balance Group'] = Comb_df['Balance'].apply(classify_balance)

print(Comb_df)
# Out:
#       CustomerId  Balance  NumOfProducts  HasCrCard  Tenure_x  IsActiveMember  \
# 0       15634602        0              1          1         2               1
# 2       15619304   159660              3          0         8               0
# 3       15701354        0              2          0         1               0
# 4       15737888   125510              1          1         2               1
# 5       15574012   113755              2          0         8               0
# ...          ...      ...            ...        ...       ...             ...
# 9995    15606229        0              2          0         5               0
# 9996    15569892    57369              1          1        10               1
# 9997    15584532        0              1          1         7               1
# 9998    15682355    75075              2          0         3               0
# 9999    15628319   130142              1          0         4               0
#
#       Exited       Name  CreditScore Geography  Gender  Age  EstimatedSalary  \
# 0          1   Hargrave          619    France  Female   42           101348
# 2          1       Onio          502    France  Female   42           113931
# 3          0       Boni          699    France  Female   39            93826
# 4          0   Mitchell          850     Spain  Female   43            79084
# 5          1        Chu          645     Spain    Male   44           149756
# ...      ...        ...          ...       ...     ...  ...              ...
# 9995       0   Obijiaku          771    France    Male   39            96270
# 9996       0  Johnstone          516    France    Male   35           101699
# 9997       1        Liu          709    France  Female   36            42085
# 9998       1  Sabbatini          772   Germany    Male   42            92888
# 9999       0     Walker          792    France  Female   28            38190
#
#           Age Group     Tenure Group Salary Group     Balance Group
# 0     Working class  Short term cust  High earner  Very low balance
# 2     Working class   Long term cust  High earner      Fair balance
# 3     Working class  Short term cust  Fair earner  Very low balance
# 4     Working class  Short term cust  Fair earner       low balance
# 5     Working class   Long term cust  High earner       low balance
# ...             ...              ...          ...               ...
# 9995  Working class  Short term cust  Fair earner  Very low balance
# 9996  Working class   Long term cust  High earner       low balance
# 9997  Working class   Long term cust   low earner  Very low balance
# 9998  Working class  Short term cust  Fair earner       low balance
# 9999        Student  Short term cust   low earner       low balance
#
# [9996 rows x 17 columns]

# %%
Comb_df
# Out:
#       CustomerId  Balance  NumOfProducts  HasCrCard  Tenure_x  IsActiveMember  \
# 0       15634602        0              1          1         2               1
# 2       15619304   159660              3          0         8               0
# 3       15701354        0              2          0         1               0
# 4       15737888   125510              1          1         2               1
# 5       15574012   113755              2          0         8               0
# ...          ...      ...            ...        ...       ...             ...
# 9995    15606229        0              2          0         5               0
# 9996    15569892    57369              1          1        10               1
# 9997    15584532        0              1          1         7               1
# 9998    15682355    75075              2          0         3               0
# 9999    15628319   130142              1          0         4               0
#
#       Exited       Name  CreditScore Geography  Gender  Age  EstimatedSalary  \
# 0          1   Hargrave          619    France  Female   42           101348
# 2          1       Onio          502    France  Female   42           113931
# 3          0       Boni          699    France  Female   39            93826
# 4          0   Mitchell          850     Spain  Female   43            79084
# 5          1        Chu          645     Spain    Male   44           149756
# ...      ...        ...          ...       ...     ...  ...              ...
# 9995       0   Obijiaku          771    France    Male   39            96270
# 9996       0  Johnstone          516    France    Male   35           101699
# 9997       1        Liu          709    France  Female   36            42085
# 9998       1  Sabbatini          772   Germany    Male   42            92888
# 9999       0     Walker          792    France  Female   28            38190
#
#           Age Group     Tenure Group Salary Group     Balance Group
# 0     Working class  Short term cust  High earner  Very low balance
# 2     Working class   Long term cust  High earner      Fair balance
# 3     Working class  Short term cust  Fair earner  Very low balance
# 4     Working class  Short term cust  Fair earner       low balance
# 5     Working class   Long term cust  High earner       low balance
# ...             ...              ...          ...               ...
# 9995  Working class  Short term cust  Fair earner  Very low balance
# 9996  Working class   Long term cust  High earner       low balance
# 9997  Working class   Long term cust   low earner  Very low balance
# 9998  Working class  Short term cust  Fair earner       low balance
# 9999        Student  Short term cust   low earner       low balance
#
# [9996 rows x 17 columns]

# %%
Comb_df_balance_exited = Comb_df.groupby('Balance Group')[['Exited']].sum()
Comb_df_balance_exited
# Out:
#                   Exited
# Balance Group
# Fair balance         213
# High balance           1
# Very low balance     526
# low balance         1297

# %%
counts_trend = Comb_df.groupby(['Salary Group', 'Balance Group']).size().reset_index(name='Count')
counts_trend
# Out:
#   Salary Group     Balance Group  Count
# 0  Fair earner      Fair balance    220
# 1  Fair earner      High balance      1
# 2  Fair earner  Very low balance    943
# 3  Fair earner       low balance   1372
# 4  High earner      Fair balance    471
# 5  High earner  Very low balance   1819
# 6  High earner       low balance   2717
# 7   low earner      Fair balance    237
# 8   low earner  Very low balance    931
# 9   low earner       low balance   1285

# %% [markdown]
# ## Most high earners have very low account compared to other group of earners this shows this account is not a savings account for them, mainly salary account, so when they changed jobs they'll probably shut down the account or become inactive

# %%
Comb_df_earners_active = Comb_df.groupby('Salary Group')[['IsActiveMember']].sum()
Comb_df_earners_active
# Out:
#               IsActiveMember
# Salary Group
# Fair earner             1311
# High earner             2565
# low earner              1272

# %%
Comb_df_active_exited = Comb_df.groupby('IsActiveMember')[['Exited']].sum()
Comb_df_active_exited
# Out:
#                 Exited
# IsActiveMember
# 0                 1302
# 1                  735

# %% [markdown]
# ## We have active members who have exited the bank

# %%
Comb_df.drop(columns=['Name'], inplace=True)

# %%
cat_columns = [col for col in Comb_df.select_dtypes('object')]

# %%
for col in cat_columns:
    sb.countplot(y=col,data=Comb_df)
    plt.title(f'Countplot of {col}')
    plt.show()

# %%
Comb_df.describe()
# Out:
#          CustomerId        Balance  NumOfProducts    HasCrCard     Tenure_x  \
# count  9.996000e+03    9996.000000    9996.000000  9996.000000  9996.000000
# mean   1.569095e+07   76481.629252       1.530412     0.515006     5.013605
# std    7.193671e+04   62400.032932       0.581674     0.499800     2.892231
# min    1.556570e+07       0.000000       1.000000     0.000000     0.000000
# 25%    1.562853e+07       0.000000       1.000000     0.000000     3.000000
# 50%    1.569074e+07   97198.000000       1.000000     1.000000     5.000000
# 75%    1.575323e+07  127643.750000       2.000000     1.000000     7.250000
# max    1.581569e+07  250898.000000       4.000000     1.000000    10.000000
#
#        IsActiveMember       Exited  CreditScore          Age  EstimatedSalary
# count     9996.000000  9996.000000   9996.00000  9996.000000      9996.000000
# mean         0.515006     0.203782    650.54962    38.921869    100090.485694
# std          0.499800     0.402829     96.66183    10.489576     57521.516409
# min          0.000000     0.000000    350.00000    18.000000        11.000000
# 25%          0.000000     0.000000    584.00000    32.000000     50973.500000
# 50%          1.000000     0.000000    652.00000    37.000000    100218.000000
# 75%          1.000000     0.000000    718.00000    44.000000    149399.500000
# max          1.000000     1.000000    850.00000    92.000000    199992.000000
